# %%
from bs4 import BeautifulSoup
import os
import pandas as pd
import requests
import html5lib
import warnings
import time
warnings.filterwarnings("ignore")

# %%
l={}
u=list()
url= "https://www.proxynova.com/proxy-server-list/country-ISO 3166-2:IL/"
respo = requests.get(url).text
soup = BeautifulSoup(respo, "html.parser")
allproxy = soup.find_all("tr")
for proxy in allproxy:
    foo = proxy.find_all("td")
try: 
    l["ip"]=foo[0].text.replace("\n","").replace("document.write(","").replace(")","").replace("\'","").replace(";","")
except:
    l["ip"]=None
try:
    l["port"]=foo[1].text.replace("\n","").replace(" ","")
except:
    l["port"]=None
try:
    l["country"]=foo[5].text.replace("\n","").replace(" ","")
except:
    l["country"]=None
if(l["port"] is not None):
    u.append(l)
l={}
print(u)
# Out:
# []

# %% [markdown]
# Get URL's:

# %%
url="https://www.bbc.com/news"
user_agent = {'User-agent': 'Mozilla/5.0'}
response2 = requests.get(url,headers=user_agent)
name=list()
urls=list()
soup2 = BeautifulSoup(response2.content, "html.parser")
tb2=soup2.find_all('li', attrs={"class":"gs-o-list-ui__item--flush gel-long-primer gs-u-display-block gs-u-float-left nw-c-nav__wide-menuitem-container"})
for r in tb2:
    urls.append(r.find('a').get('href'))
    name.append(r.get_text().strip())
#print(urls)

#add url to bbc.com
for row in urls:
    new_url="https://www.bbc.com"+row
    #print(new_url)
# Out:
# https://www.bbc.com/news/world-60525350
# https://www.bbc.com/news/coronavirus
# https://www.bbc.com/news/science-environment-56837908
# https://www.bbc.com/news/av/10462520
# https://www.bbc.com/news/world
# https://www.bbc.com/news/uk
# https://www.bbc.com/news/business
# https://www.bbc.com/news/technology
# https://www.bbc.com/news/science_and_environment
# https://www.bbc.com/news/stories
# https://www.bbc.com/news/entertainment_and_arts
# https://www.bbc.com/news/health
# https://www.bbc.com/news/world_radio_and_tv
# https://www.bbc.com/news/in_pictures
# https://www.bbc.com/news/reality_check
# https://www.bbc.com/news/newsbeat
# https://www.bbc.com/news/the_reporters

# %%
sub_title=list()
url1="https://www.bbc.com/news/world-60525350"
user_agent1 = {'User-agent': 'Mozilla/5.0'}
response1 = requests.get(url,headers=user_agent1)
soup1 = BeautifulSoup(response1.content, "html.parser")
#tb1=soup1.find_all('div', attrs={"class":"lx-stream-related-story"})
#for row in tb1:
#    sub_title.append(row.get_text().strip())

tb1=soup1.find_all('li', attrs={"class":"lx-stream__post-container"})
for row in tb1:
    sub_title.append(row.find('p').get_text())
    print(sub_title)

# %%
#import os
import selenium
from selenium import webdriver
import time
from time import sleep
from PIL import Image
import io
import requests
from webdriver_manager.chrome import ChromeDriverManager
#from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementClickInterceptedException

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Ron\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache

# %% [markdown]
# From Rotter.net:

# %%
#driver.get("https://rotter.net/news/news.php?nws=1")
url="https://rotter.net/news/news.php?nws=1"
user_agent = {'User-agent': 'Mozilla/5.0'}
response = requests.get(url,headers=user_agent)
soup = BeautifulSoup(response.content, "html.parser")
data=[]
tb = soup.find('table', dir='rtl')
table_body = tb.find('tbody')
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])
print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4440/3482957876.py in <module>
#       7 tb = soup.find('table', dir='rtl')
#       8 table_body = tb.find('tbody')
# ----> 9 rows = table_body.find_all('tr')
#      10 for row in rows:
#      11     cols = row.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# <h3>Get all news:</h3>

# %%
txt1=list()
source=list()
time=list()
i=2
driver.get("https://rotter.net/news/news.php?nws=1")
t = driver.find_element_by_xpath('/html/body/center/table')
for tr in t.find_elements_by_xpath('./tbody/tr'):
#     i+=1
#     if i==20:
#         break
    tdList = tr.find_elements_by_tag_name("td")
    if (len(tdList)==1):
        time.append("null")
        source.append("null")
        txt1.append(tdList[0].text)
    elif len(tdList)==3:
        time.append(tdList[0].text)
        source.append(tdList[1].text)
        txt1.append(tdList[2].text)
#         sleep(1)
df=pd.DataFrame({"Time":time, "Source":source, "Content":txt1})

df.to_csv("./news.csv")
df
#print(source)
#print(txt1)
#print(time)
#print("Status: %d" %(i))
# Out:
#             Time      Source  \
# 0           null        null
# 1    20:02 19/06       וואלה
# 2    20:00 19/06     רוטר.נט
# 3    20:00 19/06         ice
# 4    20:00 19/06         ice
# ..           ...         ...
# 763  20:13 18/06       מעריב
# 764  20:12 18/06        Ynet
# 765  20:11 18/06  ישראל היום
# 766  20:10 18/06        Ynet
# 767  20:08 18/06        mako
#
#                                                Content
# 0    סקירת עיתונות / מבזקים וחדשות\nמחפשים חופשה בז...
# 1    בהמשך לאיומי הסתדרות המורים: הלימודים יחלו מחר...
# 2    אליפות העולם בשחייה בודפשט: מייד גורבנקו בגמר ...
# 3      סיכום המסחר בבורסה: מקס סטוק מזנקת, תשובה מתרסק
# 4    'הצורפים' משיקים אתר סחר חדש בהשקעה של כמיליון...
# ..                                                 ...
# 763  ילד בן שמונה נפצע באורח בינוני מפגיעת אופנוע ב...
# 764  מצוד כפול באיסטנבול: "איראן הורתה לרצוח ישראלי...
# 765     אליפות העולם בשחייה: אנסטסיה גורבנקו בחצי הגמר
# 766  פעולות חילוץ בפרדס חנה: אב ובתו הקטנה נפלו לבא...
# 767  פרדס חנה: חשש לחיי אב וביתו שנפלו לבאר עם פיר ...
#
# [768 rows x 3 columns]

# %%
a= driver.find_elements
txt1=list()
source=list()
time=list()
i=2
driver.get("https://rotter.net/news/news.php?nws=1")
t = driver.find_element_by_xpath('/html/body/center/table')
for tr in t.find_elements_by_xpath('./tbody/tr'):
    tdList = tr.find_elements_by_tag_name("td")
    if (len(tdList)==1):
        time.append("null")
        source.append("null")
        txt1.append(tdList[0].text)
    elif len(tdList)==3:
        time.append(tdList[0].text)
        source.append(tdList[1].text)
        txt1.append(tdList[2].text)
#         sleep(1)
df=pd.DataFrame({"Time":time, "Source":source, "Content":txt1})

df.to_csv("./Allnews_1.csv")
df
# Out:
#             Time      Source  \
# 0           null        null
# 1    18:53 20/06      ערוץ 7
# 2    18:53 20/06       וואלה
# 3    18:52 20/06      ערוץ 7
# 4    18:50 20/06  ישראל היום
# ..           ...         ...
# 716  19:03 19/06       וואלה
# 717  19:02 19/06      ערוץ 7
# 718  18:57 19/06      ערוץ 7
# 719  18:57 19/06      ערוץ 7
# 720  18:57 19/06       וואלה
#
#                                                Content
# 0    סקירת עיתונות / מבזקים וחדשות\nמחפשים חופשה בז...
# 1    ח״כ אופיר סופר: שהחיינו וקיימנו, הממשלה האנטי ...
# 2    לפיד ובנט החליטו לפזר את הכנסת; לפיד ימונה לרא...
# 3                           שחקן המריבה בחר בהפועל ת"א
# 4                         בנט ולפיד סיכמו: הכנסת תפוזר
# ..                                                 ...
# 716                             גם מחר מתחילים ב-10:00
# 717  הסתדרות המורים ממשיכה בעיצומים: מחר הלימודים ב...
# 718                  אזעקה נשמעת במספר שכונות בירושלים
# 719  40 שנה ללבנון הראשונה: הלוחמים מישיבת שעלבים נ...
# 720           אזעקה נשמעה בירושלים, ככל הנראה עקב תקלה
#
# [721 rows x 3 columns]

# %% [markdown]
# <h4>Cyber & Economy News Flash</h4>

# %%
driver_c = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Ron\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache

# %%
## Cyber ##
txt1=list()
source=list()
time=list()
driver_c.get("https://rotter.net/news/news.php?nws=5")
cy = driver_c.find_element_by_xpath('/html/body/center/table')
for trcy in cy.find_elements_by_xpath('./tbody/tr'):
#     i+=1
#     if i==20:
#         break
    tdList = trcy.find_elements_by_tag_name("td")
    if (len(tdList)==1):
        time.append("null")
        source.append("null")
        txt1.append(tdList[0].text)
    elif len(tdList)==3:
        time.append(tdList[0].text)
        source.append(tdList[1].text)
        txt1.append(tdList[2].text)
df_cy=pd.DataFrame({"Time":time, "Source":source, "Content":txt1})
df_cy.to_csv("./Cyber_news.csv")
# df_cy

#-----------------------------------------------------------------------#
## Economy ##
sleep(5)
txt_eco=list()
src_eco=list()
time_eco=list()
driver_c.get("https://rotter.net/news/news.php?nws=3")
ec = driver_c.find_element_by_xpath('/html/body/center/table')
for tr_ec in ec.find_elements_by_xpath('./tbody/tr'):
    td_list = tr_ec.find_elements_by_tag_name("td")
    if (len(td_list)==1):
        time_eco.append("null")
        src_eco.append("null")
        txt_eco.append(td_list[0].text)
    elif len(td_list)==3:
        time_eco.append(td_list[0].text)
        src_eco.append(td_list[1].text)
        txt_eco.append(td_list[2].text)
df_eco=pd.DataFrame({"Time":time_eco, "Source":src_eco, "Content":txt_eco})
df_eco.to_csv("./economy_news.csv")
# df_eco
# Out:
#             Time       Source  \
# 0           null         null
# 1    18:40 20/06      כלכליסט
# 2    18:25 20/06    Bizportal
# 3    18:25 20/06        גלובס
# 4    18:25 20/06      כלכליסט
# ..           ...          ...
# 152  19:45 19/06      כלכליסט
# 153  19:30 19/06      כלכליסט
# 154  19:20 19/06    Bizportal
# 155  19:05 19/06        גלובס
# 156  19:00 19/06  ice finance
#
#                                                Content
# 0    מבזקי כלכלה\nמחפשים חופשה בזול? לחצו כאןלוח שנ...
# 1    דרך פרויקט הגז הגדול בהיסטוריה, קטאר תגדיל אחי...
# 2    סיפיה: מזנקת 38% - זכתה במכרז של Chery עמה תיכ...
# 3    האב, הבן ומיזם ההייטק: הסטארט-אפ פרופדו רוצה ל...
# 4    לאחר הסערה: אושר מינוי מאיר שפיגר למנכ"ל חברת ...
# ..                                                 ...
# 152  נאוויטס מצטרפת לרציו פטרוליום: תחזיק 30% מהקיד...
# 153   הסתדרות המורים תשבית גם מחר את הלימודים עד 10:00
# 154  "הסקטור הציבורי מתנהל בצורה של בריונות: מי ששו...
# 155  איך להתמודד עם שוק דובי בשלב שבו אתם מצויים בחיים
# 156  מפעליו של עידן עופר זומנו לשימוע במשרד להגנת ה...
#
# [157 rows x 3 columns]

# %%
df_cy
# Out:
#            Time    Source                                            Content
# 0          null      null  גאדג'טים. מחשבים ואינטרנט\nמחפשים חופשה בזול? ...
# 1   18:32 20/06    TGSpot  הציונים של Diablo Immortal ברצפה אבל הרווחים ב...
# 2   17:32 20/06   Gadgety  הוכרז: Realme C30 – מכשיר כניסה במחיר נמוך מ-1...
# 3   17:08 20/06    nexter  כיבתה להם את האור: איראן החליטה לנתק את החשמל ...
# 4   17:08 20/06      Ynet  מציאות או מציאות מדומה? מטא רוצה לטשטש את הגבולות
# 5   16:56 20/06    TGSpot  לא חיכה לסוני: יוטיובר יצר גרסה דקיקה וקרירה ל...
# 6   16:24 20/06  Geektime  מפתחים? סטארטאפ ישראלי חדש בנה קווסטים שישפרו ...
# 7   16:08 20/06  Geektime  מפתחים? סטארטאפ ישראלי חדש בנה לכם קווסטים שיש...
# 8   16:08 20/06   Gadgety  הוכרז: ViewFinity S8 – מסך 4K ליוצרי תוכן מבית...
# 9   15:32 20/06  Geektime     מעבר לסביבה מרובת עננים: איך עושים את זה פשוט?
# 10  15:08 20/06    nexter       "גוגל מעסיקה מספר גדול של חברים מכת קיצונית"
# 11  14:40 20/06    TGSpot    ביקורת משחק: Sniper Elite 5 – משימה סודית בהחלט
# 12  13:48 20/06   Gadgety   לקראת ההכרזה: שיאומי חושפת פרטים על ה-Poco X4 GT
# 13  13:16 20/06    nexter         כל מה שצריך לדעת על מנוי הפרימיום של טלגרם
# 14  13:16 20/06    nexter  למרות גיוס של 640 מיליון דולר: טראקס מפטרת 100...
# 15  12:32 20/06    TGSpot                 וידאו: כסא הגיימרים החדש של ד"ר גב
# 16  11:40 20/06  Geektime  איך מטמיעים מערכת הרשאות באפליקציה תוך רבע שעה...
# 17  11:40 20/06   Gadgety  הוכרזו: ROG Delta S Wireless – אוזניות גיימינג...
# 18  10:32 20/06  Geektime  אשטון קוצ'ר משקיע בסטארטאפ של פרופסור לילך עמי...
# 19  10:32 20/06    TGSpot  מנוי הפרמיום של Telegram יוצא לדרך ב-4.99 דולר...
# 20  10:24 20/06   כלכליסט  ענקית התקשורת האמריקאית קומקאסט רוכשת את Levl ...
# 21  10:08 20/06   כלכליסט  חשד: מתקפת סייבר איראנית הפעילה אזעקות שווא בי...
# 22  09:40 20/06  Geektime  האם האקרים איראניים הצליחו להפעיל את האזעקות ב...
# 23  09:32 20/06   Gadgety  טלגרם חוגגת 700 מיליון משתמשים ומשיקה גרסת פרי...
# 24  06:08 20/06   כלכליסט  ענקית התקשורת האמריקאית קומקאסט רוכשת את Levl ...
# 25  21:32 19/06    TGSpot         הסוף של גוגל ברוסיה: הגישה בקשה לפשיטת רגל
# 26  19:08 19/06    TGSpot  טלפון הדגל של ויוו, X80 Pro, הוכרז באירופה והמ...

# %% [markdown]
# <h4>Latest 3000 scoops:</h4>

# %%
driver_sc = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Ron\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache

# %%
titl=list()
time_s=list()
comm_n=list()
views=list()
i=0
driver_sc.get("https://rotter.net/forum/listforumd.php")
sc = driver_sc.find_element_by_xpath('/html/body/table[5]/tbody/tr/td[2]/table/tbody/tr/td/table[2]')
for trsc in sc.find_elements_by_xpath('./tbody/tr'):
#     if i<=20:
    tdList = trsc.find_elements_by_tag_name("td")
    if (len(tdList)==6):
        titl.append(tdList[1].text)
        time_s.append(tdList[2].text)
        comm_n.append(tdList[4].text)
        views.append(tdList[5].text)

#         if(tdList[2]):
#             t_elem = tdList[2].find_elements_by_tag_name("font")
#             if ("/" in t_elem[0].text.split()):
#                 print(t_elem[0].text.split())
     
#     i+=1
df_scoops = pd.DataFrame({"Title":titl, "Date":time_s, "Number of Comments":comm_n, "Number of Views":views})
df_scoops.to_csv("./3000Scoops_news.csv")
df_scoops
    # print("Titles: \n",titl)
# print("\nTime: \n", time_s)
# print("\nComments number: \n", comm_n)
# print("\nViews number: \n", views)
# Out:
#                                                   Title  \
# 0                                                כותרות
# 1        אזכרה במלאת 10 שנים לפטירתו של אבי מורי ז''...
# 2        המלחמה באוקראינה יום 116 (אשכול 103) | אשכו...
# 3               השר זאב אלקין : לעולם לא אשב תחת נתניהו
# 4        יפן: בית משפט באוסקה קבע: האיסור על נישואיי...
# ...                                                 ...
# 2996     טל שירתה כמש''קית נפגעים - ונהרגה בתאונה: '...
# 2997     עוד עזיבה בלשכת רהמ: נעמי ששון העוזרת האישי...
# 2998          ירדן תכפיל את אספקת החשמל לרשות הפלסטינית
# 2999     בית המשפט דחה על הסף תביעה של אלדד יניב נגד...
# 3000     הדיל של ימינה והעבודה נדחה| חוק הנצחת הרב ק...
#
#                            Date Number of Comments Number of Views
# 0                           שעה             תגובות           ניצפה
# 1              Noam\n06/20/2022                 52           14505
# 2     אסטריקס ושות'\n06/20/2022                 59           31574
# 3           האדמירל\n06/20/2022                 11            1720
# 4           יוסריאן\n06/20/2022                 61            9757
# ...                         ...                ...             ...
# 2996     תלאביביבדם\n05/31/2022                 32           21342
# 2997         micmic\n05/31/2022                 85           23036
# 2998          טנגרם\n05/31/2022                  8            4533
# 2999   עבד לעם קדוש\n05/31/2022                 25           12714
# 3000          בנג'ו\n05/31/2022                 24            7245
#
# [3001 rows x 4 columns]

# %%
df1=pd.read_csv("./news.csv")
df1
# Out:
#      Unnamed: 0         Time      Source  \
# 0             0          NaN         NaN
# 1             1  20:02 19/06       וואלה
# 2             2  20:00 19/06     רוטר.נט
# 3             3  20:00 19/06         ice
# 4             4  20:00 19/06         ice
# ..          ...          ...         ...
# 763         763  20:13 18/06       מעריב
# 764         764  20:12 18/06        Ynet
# 765         765  20:11 18/06  ישראל היום
# 766         766  20:10 18/06        Ynet
# 767         767  20:08 18/06        mako
#
#                                                Content
# 0    סקירת עיתונות / מבזקים וחדשות\nמחפשים חופשה בז...
# 1    בהמשך לאיומי הסתדרות המורים: הלימודים יחלו מחר...
# 2    אליפות העולם בשחייה בודפשט: מייד גורבנקו בגמר ...
# 3      סיכום המסחר בבורסה: מקס סטוק מזנקת, תשובה מתרסק
# 4    'הצורפים' משיקים אתר סחר חדש בהשקעה של כמיליון...
# ..                                                 ...
# 763  ילד בן שמונה נפצע באורח בינוני מפגיעת אופנוע ב...
# 764  מצוד כפול באיסטנבול: "איראן הורתה לרצוח ישראלי...
# 765     אליפות העולם בשחייה: אנסטסיה גורבנקו בחצי הגמר
# 766  פעולות חילוץ בפרדס חנה: אב ובתו הקטנה נפלו לבא...
# 767  פרדס חנה: חשש לחיי אב וביתו שנפלו לבאר עם פיר ...
#
# [768 rows x 4 columns]

# %%
search_url="https://www.bbc.com/news/world-60525350"
driver.get("https://www.bbc.com/news/world-60525350")
articles=driver.find_elements_by_tag_name("article")
for article in articles:
    header = article.find_element_by_class_name("gs-u-mb+ gel-body-copy qa-post-body")
    print(header.text)
#driver.quit()
#next_page=driver.find_element_by_class_name("lx-pagination__btn gs-u-mr+ qa-pagination-next-page lx-pagination__btn--active")
#next_page.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11072/789725495.py in <module>
#       3 articles=driver.find_elements_by_tag_name("article")
#       4 for article in articles:
# ----> 5     header = article.find_element_by_class_name("gs-u-mb+ gel-body-copy qa-post-body")
#       6     print(header.text)
#       7 #driver.quit()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     471                       DeprecationWarning,
#     472                       stacklevel=2)
# --> 473         return self.find_element(by=By.CLASS_NAME, value=name)
#     474
#     475     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     761             value = '[name="%s"]' % value
#     762
# --> 763         return self._execute(Command.FIND_CHILD_ELEMENT,
#     764                              {"using": by, "value": value})['value']
#     765
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     738             params = {}
#     739         params['id'] = self._id
# --> 740         return self._parent.execute(command, params)
#     741
#     742     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".gs-u-mb+ gel-body-copy qa-post-body"}
#   (Session info: chrome=102.0.5005.63)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008ED953+2414931]
# 	Ordinal0 [0x0087F5E1+1963489]
# 	Ordinal0 [0x0076C6B8+837304]
# 	Ordinal0 [0x00799500+1021184]
# 	Ordinal0 [0x0079979B+1021851]
# 	Ordinal0 [0x0078FCF1+982257]
# 	Ordinal0 [0x007B44E4+1131748]
# 	Ordinal0 [0x0078FC74+982132]
# 	Ordinal0 [0x007B46B4+1132212]
# 	Ordinal0 [0x007C4812+1198098]
# 	Ordinal0 [0x007B42B6+1131190]
# 	Ordinal0 [0x0078E860+976992]
# 	Ordinal0 [0x0078F756+980822]
# 	GetHandleVerifier [0x00B5CC62+2510274]
# 	GetHandleVerifier [0x00B4F760+2455744]
# 	GetHandleVerifier [0x0097EABA+551962]
# 	GetHandleVerifier [0x0097D916+547446]
# 	Ordinal0 [0x00885F3B+1990459]
# 	Ordinal0 [0x0088A898+2009240]
# 	Ordinal0 [0x0088A985+2009477]
# 	Ordinal0 [0x00893AD1+2046673]
# 	BaseThreadInitThunk [0x767D6739+25]
# 	RtlGetFullPathName_UEx [0x77698FEF+1215]
# 	RtlGetFullPathName_UEx [0x77698FBD+1165]
